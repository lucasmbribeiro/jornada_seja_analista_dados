# %%
import pandas as pd
import numpy as np

# %%
df_produto = pd.read_csv('./base/produto.csv')

# %%
df_produto.head()
# Out:
#                          id_produto   nm_categoria_produto  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    comprimento_nm_produto  comprimento_descricao_produto  qtd_fotos_produto  \
# 0                    40.0                          287.0                1.0
# 1                    44.0                          276.0                1.0
# 2                    46.0                          250.0                1.0
# 3                    27.0                          261.0                1.0
# 4                    37.0                          402.0                4.0
#
#    peso_produto_gramas  comprimento_produto_cm  altura_produto_cm  \
# 0                225.0                    16.0               10.0
# ...

# %%
df_produto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id_produto                     32951 non-null  object
#  1   nm_categoria_produto           32341 non-null  object
#  2   comprimento_nm_produto         32341 non-null  float64
#  3   comprimento_descricao_produto  32341 non-null  float64
#  4   qtd_fotos_produto              32341 non-null  float64
#  5   peso_produto_gramas            32949 non-null  float64
#  6   comprimento_produto_cm         32949 non-null  float64
#  7   altura_produto_cm              32949 non-null  float64
#  8   largura_produto_cm             32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ## ADICIONAR
# ***

# %%
df_produto['teste'] = df_produto.index * 3

# %%
df_produto.head()
# Out:
#                          id_produto   nm_categoria_produto  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    comprimento_nm_produto  comprimento_descricao_produto  qtd_fotos_produto  \
# 0                    40.0                          287.0                1.0
# 1                    44.0                          276.0                1.0
# 2                    46.0                          250.0                1.0
# 3                    27.0                          261.0                1.0
# 4                    37.0                          402.0                4.0
#
#    peso_produto_gramas  comprimento_produto_cm  altura_produto_cm  \
# 0                225.0                    16.0               10.0
# ...

# %%
df_produto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id_produto                     32951 non-null  object
#  1   nm_categoria_produto           32341 non-null  object
#  2   comprimento_nm_produto         32341 non-null  float64
#  3   comprimento_descricao_produto  32341 non-null  float64
#  4   qtd_fotos_produto              32341 non-null  float64
#  5   peso_produto_gramas            32949 non-null  float64
#  6   comprimento_produto_cm         32949 non-null  float64
#  7   altura_produto_cm              32949 non-null  float64
#  8   largura_produto_cm             32949 non-null  float64
#  9   teste                          32951 non-null  int64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.5+ MB

# %%
df_produto['largura_produto_cm'] * 2
# Out:
# 0        28.0
# 1        40.0
# 2        30.0
# 3        52.0
# 4        26.0
#          ...
# 32946    80.0
# 32947    32.0
# 32948    54.0
# 32949    40.0
# 32950    14.0
# Name: largura_produto_cm, Length: 32951, dtype: float64

# %% [markdown]
# altura * comprimento * largura

# %%
df_produto['caixa_em_m3'] =  df_produto['altura_produto_cm'] * df_produto['comprimento_produto_cm'] * df_produto['largura_produto_cm']

# %%
df_produto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id_produto                     32951 non-null  object
#  1   nm_categoria_produto           32341 non-null  object
#  2   comprimento_nm_produto         32341 non-null  float64
#  3   comprimento_descricao_produto  32341 non-null  float64
#  4   qtd_fotos_produto              32341 non-null  float64
#  5   peso_produto_gramas            32949 non-null  float64
#  6   comprimento_produto_cm         32949 non-null  float64
#  7   altura_produto_cm              32949 non-null  float64
#  8   largura_produto_cm             32949 non-null  float64
#  9   teste                          32951 non-null  int64
#  10  caixa_em_m3                    32949 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# ## OLHANDO OS DADOS NULOS (NAN)
# ***

# %%
df_produto['nm_categoria_produto'].unique()
# Out:
# array(['perfumaria', 'artes', 'esporte_lazer', 'bebes',
#        'utilidades_domesticas', 'instrumentos_musicais', 'cool_stuff',
#        'moveis_decoracao', 'eletrodomesticos', 'brinquedos',
#        'cama_mesa_banho', 'construcao_ferramentas_seguranca',
#        'informatica_acessorios', 'beleza_saude', 'malas_acessorios',
#        'ferramentas_jardim', 'moveis_escritorio', 'automotivo',
#        'eletronicos', 'fashion_calcados', 'telefonia', 'papelaria',
#        'fashion_bolsas_e_acessorios', 'pcs', 'casa_construcao',
#        'relogios_presentes', 'construcao_ferramentas_construcao',
#        'pet_shop', 'eletroportateis', 'agro_industria_e_comercio', nan,
#        'moveis_sala', 'sinalizacao_e_seguranca', 'climatizacao',
#        'consoles_games', 'livros_interesse_geral',
#        'construcao_ferramentas_ferramentas',
#        'fashion_underwear_e_moda_praia', 'fashion_roupa_masculina',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
# ...

# %%
df_produto['nm_categoria_produto'].value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# casa_conforto_2                     5
# fashion_roupa_infanto_juvenil       5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: nm_categoria_produto, Length: 73, dtype: int64

# %% [markdown]
# ## Filtrar um Valor Nulo
# ```notna.()```
# ***

# %%
#df_produto = df_produto[ df_produto['nm_categoria_produto'].notna() ] COMO ATRIBUIR O FILTRO DE VOLTA

df_produto[ df_produto['nm_categoria_produto'].notna() ]
# Out:
#                              id_produto               nm_categoria_produto  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        comprimento_nm_produto  comprimento_descricao_produto  \
# ...

# %% [markdown]
# ## Preencher um Valor Nulo
# ```fillna()```

# %%
df_produto.fillna(0)
# Out:
#                              id_produto               nm_categoria_produto  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        comprimento_nm_produto  comprimento_descricao_produto  \
# ...

# %%
#df_produto['nm_categoria_produto'] = 
np.where(df_produto['nm_categoria_produto'].notna() == False, 'SEM DESCRIÇÃO', df_produto['nm_categoria_produto'])
# Out:
# array(['perfumaria', 'artes', 'esporte_lazer', ..., 'cama_mesa_banho',
#        'informatica_acessorios', 'cama_mesa_banho'], dtype=object)

# %% [markdown]
# ## Remover a linha nula
# ```dropna()```

# %%
df_produto.dropna()
# Out:
#                              id_produto               nm_categoria_produto  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        comprimento_nm_produto  comprimento_descricao_produto  \
# ...

# %% [markdown]
# ## Excluir
# ***

# %%
del df_produto['teste']

# %%
df_produto.head()
# Out:
#                          id_produto   nm_categoria_produto  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    comprimento_nm_produto  comprimento_descricao_produto  qtd_fotos_produto  \
# 0                    40.0                          287.0                1.0
# 1                    44.0                          276.0                1.0
# 2                    46.0                          250.0                1.0
# 3                    27.0                          261.0                1.0
# 4                    37.0                          402.0                4.0
#
#    peso_produto_gramas  comprimento_produto_cm  altura_produto_cm  \
# 0                225.0                    16.0               10.0
# ...

# %% [markdown]
# ***
#
# # BASE DE PAGAMENTOS

# %%
df_pagto = pd.read_csv('./base/pagamento.csv')
df_pagto.head()
# Out:
#                           id_pedido  sequencial_pagamento tp_pagamento  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                     1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                     1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                     1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                     1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                     1  credit_card
#
#    qtd_parcelas  vl_pagamento
# 0             8         99.33
# 1             1         24.39
# 2             1         65.71
# 3             8        107.78
# 4             2        128.45

# %%
df_pagto['vl_parcela'] = round(df_pagto['vl_pagamento'] / df_pagto['qtd_parcelas'], 2)

# %%
df_pagto.head()
# Out:
#                           id_pedido  sequencial_pagamento tp_pagamento  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                     1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                     1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                     1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                     1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                     1  credit_card
#
#    qtd_parcelas  vl_pagamento  vl_parcela
# 0             8         99.33       12.42
# 1             1         24.39       24.39
# 2             1         65.71       65.71
# 3             8        107.78       13.47
# 4             2        128.45       64.22
